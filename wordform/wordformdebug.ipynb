# %%
import wordform
import sys
import re
import tensorflow as tf
from tensorflow.python.platform import gfile
import os
import numpy as np
from tensorflow.models.rnn.translate import data_utils

_DIGIT_RE = re.compile(r"\d")
_PAD = "_PAD"
_GO = "_GO"
_EOS = "_EOS"
_UNK = "_UNK"
_START_VOCAB = [_PAD, _GO, _EOS, _UNK]

PAD_ID = 0
GO_ID = 1
EOS_ID = 2
UNK_ID = 3

sys.argv.extend(["--train_dir=/data/korpora_train",
                "--data_dir=/data/korpora",
                "--size=1024",
                "--learning_rate=1.0",
                "--learning_rate_decay_factor=0.95",
                "--num_layers=2",
                "--vocab_size=3200",
                "--steps_per_checkpoint=100"])

#data_dir = "/data/korpora"
_,_,input_dev,target_dev,_,_ = wordform.prepare_korpora_data("/data/korpora", 5000)
#target_data_path = os.path.join(data_dir,
#                                 "korpora_train.target")
#target_vocab_path = os.path.join(data_dir,
#                                 "vocab%d.target" % 4000)
#create_vocabulary(target_vocab_path, target_data_path, 200, wordform.char_tokenizer)
#tv, rev_target_vocab = data_utils.initialize_vocabulary(target_vocab_path)
#for r in rev_target_vocab[:20]:
#    print(r, [r])
#print(data_utils.sentence_to_token_ids("Grollen", tv, wordform.bigram_tokenizer))
#print wordform.bigram_tokenizer()
#print([w for w in "Geißel".decode("utf-8")])
#print(["Geißel".decode("utf-8")])
with tf.Session() as sess:
    # Create model and load parameters.
    model = wordform.create_model(sess, True)
    dev_set = wordform.read_data(input_dev, target_dev)
    eval_datas = wordform.evaluate_valid(model, sess, dev_set, 1)
    hits = np.zeros(len(eval_datas))
    for i in range(len(eval_datas)):
        hits[i] = 1 if eval_datas[i][1][1:eval_datas[i][1].rindex(".")] == eval_datas[i][2] else 0
        if not hits[i]:
            print("wrong: ", eval_datas[i])
    accuracy = sum(hits)/len(eval_datas)
    print("%d datas, accuracy %.5f" % (len(eval_datas), accuracy))
# Out:
# data loaded:  2814766
# Reading model parameters from /data/korpora_train/korpora.ckpt-27700
#   reading data line 100000
#   eval: bucket 0 perplexity 1.00
#   sampled valid (i,t,o) schöner  #schön. schön
#   eval: bucket 1 perplexity 1.21
#   sampled valid (i,t,o) präsentiert     #präsentieren.   präsentieren
#   eval: bucket 2 perplexity 2.39
#   sampled valid (i,t,o) Silberzwiebelzwischenlager        #Silberzwiebelzwischenlager.      Silberorieschingschenlager
#   eval: bucket 3 perplexity 520.13
#   sampled valid (i,t,o) -korrespondentin-ueber-attacke-auf-ard-team-a-000000.html            #-korrespondentin-ueber-attacke-auf-ard-team-a-000000.html.          Inrerereonerreonerbronsvkrsmonololtm
# ('wrong: ', ['Hollywood-Studios ', '#Hollywood-Studio.', 'HollywooooStudio'])
# ('wrong: ', ['Airbus-Auftrag   ', '#Airbus-Auftrag. ', 'Airkus-Auftrag'])
# ('wrong: ', ['erlegen      ', '#erliegen.    ', 'erlegen'])
# ('wrong: ', ['Konkret      ', '#konkret.    ', 'Konkret'])
# ('wrong: ', ['scheppernden    ', '#scheppernden.  ', 'scheppernd'])
# ('wrong: ', ['AUTOKONZERN    ', '#AUTOKONZERN.  ', 'Autorsertt'])
# ('wrong: ', ['Bewaffneten    ', '#Bewaffnete.   ', 'Bewaffnene'])
# ('wrong: ', ['wegzufahren    ', '#wegfahren.   ', 'wegzahahn'])
# ('wrong: ', ['eroberten     ', '#erobert.    ', 'erobern'])
# ('wrong: ', ['zugeh\xc3\xb6rt      ', '#zuh\xc3\xb6ren.    ', 'zugeren'])
# ('wrong: ', ['Silberzwiebelzwischenlager       ', '#Silberzwiebelzwischenlager.     ', 'Silberorieschingschenlager'])
# ('wrong: ', ['Grand-Slam-Turniere          ', '#Grand-Slam-Turnier.         ', 'Grand-d--T-Tmenieren'])
# ('wrong: ', ['-attackiert-a-000000.html       ', '#-attackiert-a-000000.html.     ', 'Acttt-t-t-000000gl00col'])
# ('wrong: ', ['Feuerwerkslasters           ', '#Feuerwerkslasters.         ', 'Feuerwerkslalaers'])
# ('wrong: ', ['Grand-Slam-Turniere          ', '#Grand-Slam-Turnier.         ', 'Grand-d--T-Tmenieren'])
# ('wrong: ', ['Cannibal-Corpse-Dokumentation     ', '#Cannibal-Corpse-Dokumentation.   ', 'Cannore-e-e-e-e-e-mellation'])
# ('wrong: ', ['Peking-Moskau-Berlin          ', '#Peking-Moskau-Berlin.        ', 'Pekingososkaperlrlin'])
# ('wrong: ', ['Burn-out-Dauerbeschuss         ', '#Burn-out-Dauerbeschuss.       ', 'Burn-Dututererflbehu\xc3\x9f'])
# ('wrong: ', ['Da-wei\xc3\x9f-man-was-man-hat        ', '#Da-wei\xc3\x9f-man-was-man-hat.      ', 'Daeimaeiman-s-man-Mut'])
# ('wrong: ', ['\xc3\x9cberraschungseierh\xc3\xbclsen        ', '#\xc3\x9cberraschungseierh\xc3\xbclsen.      ', '\xc3\x9cberraschungsenriesen'])
# ('wrong: ', ['Feuerwerkslasters           ', '#Feuerwerkslasters.         ', 'Feuerwerkslalaers'])
# ('wrong: ', ['Gef\xc3\xa4ngnisverwaltung          ', '#Gef\xc3\xa4ngnisverwaltung.        ', 'Gef\xc3\xa4ngsvsverwaltung'])
# ('wrong: ', ['Burn-out-Dauerbeschuss         ', '#Burn-out-Dauerbeschuss.       ', 'Burn-Dututererflbehu\xc3\x9f'])
# ('wrong: ', ['Transformatorhauses          ', '#Transformatorhauses.        ', 'Transfmamarhauauses'])
# ('wrong: ', ['Supermax-Gef\xc3\xa4ngnisse          ', '#Supermax-Gef\xc3\xa4ngnisse.        ', 'Superm-Heief\xc3\xa4ngnisse'])
# ('wrong: ', ['Silex-Gesch\xc3\xa4ftsf\xc3\xbchrer         ', '#Silex-Gesch\xc3\xa4ftsf\xc3\xbchrer.       ', 'Sileleh\xc3\xa4h\xc3\xa4h\xc3\xa4ftsf\xc3\xbchrer'])
# ('wrong: ', ['leistungssteigerne           ', '#leistungssteigerne.         ', 'leistungssteigern'])
# ('wrong: ', ['Legendenpotential           ', '#Legendenpotential.         ', 'Legendenpopontial'])
# ('wrong: ', ['Nichtraucherschutz-Kampagnen      ', '#Nichtraucherschutz-Kampagnen.    ', 'Nichtrchschuchschuamampaisen'])
# ('wrong: ', ['Tourismus-Ausstellung         ', '#Tourismus-Ausstellung.       ', 'TossmuisauAusstellung'])
# ('wrong: ', ['Leitwolf-Ideologie           ', '#Leitwolf-Ideologie.         ', 'Leitwilflfdeogogie'])
# ('wrong: ', ['Hochsicherheitsgef\xc3\xa4ngnis        ', '#Hochsicherheitsgef\xc3\xa4ngnis.      ', 'Hochcherheitersgefefie'])
# ('wrong: ', ['Vertriebsgesellschaft         ', '#Vertriebsgesellschaft.       ', 'Vertrirtsgesellschaft'])
# ('wrong: ', ['Sinaloa-Buchhalter           ', '#Sinaloa-Buchhalter.         ', 'Sinaloa-a-lthalter'])
# ('wrong: ', ['US-Marineinfanterie          ', '#US-Marineinfanterie.        ', 'US-Minineieiinterie'])
# ('wrong: ', ['Peking-Moskau-Berlin          ', '#Peking-Moskau-Berlin.        ', 'Pekingososkaperlrlin'])
# ('wrong: ', ['Kundenzufriedenheits-Studien      ', '#Kundenzufriedenheits-Studien.    ', 'Kundenzuieiedeeitstsdidien'])
# ('wrong: ', ['Schlechte-Nachrichten-\xc3\x9cberbringen   ', '#Schlechte-Nachrichten-\xc3\x9cberbringen. ', 'Schlechte-Nachsichbrerbrinbrn'])
# ('wrong: ', ['ELEKTROAUTO-STUDIE           ', '#ELEKTROAUTO-STUDIE.         ', 'DIsnululStSTStnoie'])
# ('wrong: ', ['Berlinale-Direktor           ', '#Berlinale-Direktor.         ', 'Berlinale-rektoror'])
# ('wrong: ', ['Literaturnobelpreistr\xc3\xa4ger       ', '#Literaturnobelpreistr\xc3\xa4ger.     ', 'Literararaelobpreisteiger'])
# ('wrong: ', ['Kinderkrankenhaus           ', '#Kinderkrankenhaus.         ', 'Kinderkranspnhaus'])
# ('wrong: ', ['mitaufgewirbelten           ', '#mitaufgewirbelten.         ', 'mitatagerbrbelten'])
# ('wrong: ', ['Zentralverriegelung          ', '#Zentralverriegelung.        ', 'Zentraralveregegung'])
# ('wrong: ', ['h\xc3\xb6chstwahrscheinlich          ', '#h\xc3\xb6chstwahrscheinlich.        ', 'h\xc3\xb6chwawahrscheinlich'])
# ('wrong: ', ['wegen"unrichtiger           ', '#wegen"unrichtiger.         ', 'wegegew\xc3\xb6chtitiger'])
# ('wrong: ', ['Artilleriegesch\xc3\xbctzen          ', '#Artilleriegesch\xc3\xbctz.         ', 'Artitiergegesch\xc3\xbctzen'])
# ('wrong: ', ['Ingenieurwissenschaften        ', '#Ingenieurwissenschaft.       ', 'Ingenieueuissenschaft'])
# ('wrong: ', ['Silex-Gesch\xc3\xa4ftsf\xc3\xbchrer         ', '#Silex-Gesch\xc3\xa4ftsf\xc3\xbchrer.       ', 'Sileleh\xc3\xa4h\xc3\xa4h\xc3\xa4ftsf\xc3\xbchrer'])
# ('wrong: ', ['Uno-Menschenrechtsrat         ', '#Uno-Menschenrechtsrat.       ', 'Uno-Mensenenrechtsrat'])
# ('wrong: ', ['Nordkorea-Analyst           ', '#Nordkorea-Analyst.         ', 'NordkorealAnalyst'])
# ('wrong: ', ['Sechs-Parteien-Gespr\xc3\xa4che        ', '#Sechs-Parteien-Gespr\xc3\xa4che.      ', 'Sech-G-Grt-Geiespres\xc3\xa4che'])
# ('wrong: ', ['Sparkassenfiliale           ', '#Sparkassenfiliale.         ', 'Sparkassenkassale'])
# ('wrong: ', ['Reisebekanntschaften          ', '#Reisebekanntschaft.         ', 'Reekekekananschaft'])
# ('wrong: ', ['Eisenhower-Doktrin           ', '#Eisenhower-Doktrin.         ', 'Eiservower-D-Linsen'])
# ('wrong: ', ['-korrespondentin-ueber-attacke-auf-ard-team-a-000000.html           ', '#-korrespondentin-ueber-attacke-auf-ard-team-a-000000.html.         ', 'Inrerereonerreonerbronsvkrsmonololtm'])
# ('wrong: ', ['-korrespondentin-ueber-attacke-auf-ard-team-a-000000.html           ', '#-korrespondentin-ueber-attacke-auf-ard-team-a-000000.html.         ', 'Inrerereonerreonerbronsvkrsmonololtm'])
# ('wrong: ', ['000-Milliarden-Dollar-Konjunkturpaket                     ', '#000-Milliarden-Dollar-Konjunkturpaket.                   ', '000-Milliardenunlar--Dktktkturkeurt'])
# ('wrong: ', ['usend-kilometer-reichweite-a-000000.html                    ', '#usend-kilometer-reichweite-a-000000.html.                  ', 'kiusenDalotehrterrtenzteisisicheht'])
# ('wrong: ', ['-korrespondentin-ueber-attacke-auf-ard-team-a-000000.html           ', '#-korrespondentin-ueber-attacke-auf-ard-team-a-000000.html.         ', 'Inrerereonerreonerbronsvkrsmonololtm'])
# ('wrong: ', ['usend-kilometer-reichweite-a-000000.html                    ', '#usend-kilometer-reichweite-a-000000.html.                  ', 'kiusenDalotehrterrtenzteisisicheht'])
# ('wrong: ', ['-verursacht-regen-in-kalifornien-a-000000.html                 ', '#-verursacht-regen-in-kalifornien-a-000000.html.               ', '\xc3\x9cbert-sachersaint-t-t-'])
# ('wrong: ', ['-verursacht-regen-in-kalifornien-a-000000.html                 ', '#-verursacht-regen-in-kalifornien-a-000000.html.               ', '\xc3\x9cbert-sachersaint-t-t-'])
# ('wrong: ', ['-korrespondentin-ueber-attacke-auf-ard-team-a-000000.html           ', '#-korrespondentin-ueber-attacke-auf-ard-team-a-000000.html.         ', 'Inrerereonerreonerbronsvkrsmonololtm'])
# ('wrong: ', ['-hackerangriffe-wall-street-journal-ausgespaeht-a-000000.html         ', '#-hackerangriffe-wall-street-journal-ausgespaeht-a-000000.html.       ', 'Inkekengringringt-'])
# ('wrong: ', ['china-mehrere-tote-bei-explosion-auf-feuerwerkslaster-a-000000.html      ', '#china-mehrere-tote-bei-explosion-auf-feuerwerkslaster-a-000000.html.    ', 'chininMamarnere-e-lolon-loloeismonbrpion'])
# ('wrong: ', ['-verursacht-regen-in-kalifornien-a-000000.html                 ', '#-verursacht-regen-in-kalifornien-a-000000.html.               ', '\xc3\x9cbert-sachersaint-t-t-'])
# ('wrong: ', ['-verursacht-regen-in-kalifornien-a-000000.html                 ', '#-verursacht-regen-in-kalifornien-a-000000.html.               ', '\xc3\x9cbert-sachersaint-t-t-'])
# ('wrong: ', ['-hackerangriffe-wall-street-journal-ausgespaeht-a-000000.html         ', '#-hackerangriffe-wall-street-journal-ausgespaeht-a-000000.html.       ', 'Inkekengringringt-'])
# ('wrong: ', ['-korrespondentin-ueber-attacke-auf-ard-team-a-000000.html           ', '#-korrespondentin-ueber-attacke-auf-ard-team-a-000000.html.         ', 'Inrerereonerreonerbronsvkrsmonololtm'])
# ('wrong: ', ['000-Milliarden-Dollar-Konjunkturpaket                     ', '#000-Milliarden-Dollar-Konjunkturpaket.                   ', '000-Milliardenunlar--Dktktkturkeurt'])
# ('wrong: ', ['china-mehrere-tote-bei-explosion-auf-feuerwerkslaster-a-000000.html      ', '#china-mehrere-tote-bei-explosion-auf-feuerwerkslaster-a-000000.html.    ', 'chininMamarnere-e-lolon-loloeismonbrpion'])
# ('wrong: ', ['-hackerangriffe-wall-street-journal-ausgespaeht-a-000000.html         ', '#-hackerangriffe-wall-street-journal-ausgespaeht-a-000000.html.       ', 'Inkekengringringt-'])
# ('wrong: ', ['-verursacht-regen-in-kalifornien-a-000000.html                 ', '#-verursacht-regen-in-kalifornien-a-000000.html.               ', '\xc3\x9cbert-sachersaint-t-t-'])
# ('wrong: ', ['-verursacht-regen-in-kalifornien-a-000000.html                 ', '#-verursacht-regen-in-kalifornien-a-000000.html.               ', '\xc3\x9cbert-sachersaint-t-t-'])
# ('wrong: ', ['-korrespondentin-ueber-attacke-auf-ard-team-a-000000.html           ', '#-korrespondentin-ueber-attacke-auf-ard-team-a-000000.html.         ', 'Inrerereonerreonerbronsvkrsmonololtm'])
# ('wrong: ', ['000-Milliarden-Dollar-Konjunkturpaket                     ', '#000-Milliarden-Dollar-Konjunkturpaket.                   ', '000-Milliardenunlar--Dktktkturkeurt'])
# ('wrong: ', ['000-Milliarden-Dollar-Konjunkturpaket                     ', '#000-Milliarden-Dollar-Konjunkturpaket.                   ', '000-Milliardenunlar--Dktktkturkeurt'])
# ('wrong: ', ['china-mehrere-tote-bei-explosion-auf-feuerwerkslaster-a-000000.html      ', '#china-mehrere-tote-bei-explosion-auf-feuerwerkslaster-a-000000.html.    ', 'chininMamarnere-e-lolon-loloeismonbrpion'])
# ('wrong: ', ['china-mehrere-tote-bei-explosion-auf-feuerwerkslaster-a-000000.html      ', '#china-mehrere-tote-bei-explosion-auf-feuerwerkslaster-a-000000.html.    ', 'chininMamarnere-e-lolon-loloeismonbrpion'])
# ('wrong: ', ['-verursacht-regen-in-kalifornien-a-000000.html                 ', '#-verursacht-regen-in-kalifornien-a-000000.html.               ', '\xc3\x9cbert-sachersaint-t-t-'])
# ('wrong: ', ['-hackerangriffe-wall-street-journal-ausgespaeht-a-000000.html         ', '#-hackerangriffe-wall-street-journal-ausgespaeht-a-000000.html.       ', 'Inkekengringringt-'])
# ('wrong: ', ['000-Milliarden-Dollar-Konjunkturpaket                     ', '#000-Milliarden-Dollar-Konjunkturpaket.                   ', '000-Milliardenunlar--Dktktkturkeurt'])
# ('wrong: ', ['usend-kilometer-reichweite-a-000000.html                    ', '#usend-kilometer-reichweite-a-000000.html.                  ', 'kiusenDalotehrterrtenzteisisicheht'])
# ('wrong: ', ['-korrespondentin-ueber-attacke-auf-ard-team-a-000000.html           ', '#-korrespondentin-ueber-attacke-auf-ard-team-a-000000.html.         ', 'Inrerereonerreonerbronsvkrsmonololtm'])
# ('wrong: ', ['-hackerangriffe-wall-street-journal-ausgespaeht-a-000000.html         ', '#-hackerangriffe-wall-street-journal-ausgespaeht-a-000000.html.       ', 'Inkekengringringt-'])
# ('wrong: ', ['-verursacht-regen-in-kalifornien-a-000000.html                 ', '#-verursacht-regen-in-kalifornien-a-000000.html.               ', '\xc3\x9cbert-sachersaint-t-t-'])
# ('wrong: ', ['-korrespondentin-ueber-attacke-auf-ard-team-a-000000.html           ', '#-korrespondentin-ueber-attacke-auf-ard-team-a-000000.html.         ', 'Inrerereonerreonerbronsvkrsmonololtm'])
# ('wrong: ', ['-hackerangriffe-wall-street-journal-ausgespaeht-a-000000.html         ', '#-hackerangriffe-wall-street-journal-ausgespaeht-a-000000.html.       ', 'Inkekengringringt-'])
# ('wrong: ', ['000-Milliarden-Dollar-Konjunkturpaket                     ', '#000-Milliarden-Dollar-Konjunkturpaket.                   ', '000-Milliardenunlar--Dktktkturkeurt'])
# ('wrong: ', ['china-mehrere-tote-bei-explosion-auf-feuerwerkslaster-a-000000.html      ', '#china-mehrere-tote-bei-explosion-auf-feuerwerkslaster-a-000000.html.    ', 'chininMamarnere-e-lolon-loloeismonbrpion'])
# ('wrong: ', ['usend-kilometer-reichweite-a-000000.html                    ', '#usend-kilometer-reichweite-a-000000.html.                  ', 'kiusenDalotehrterrtenzteisisicheht'])
# ('wrong: ', ['000-Milliarden-Dollar-Konjunkturpaket                     ', '#000-Milliarden-Dollar-Konjunkturpaket.                   ', '000-Milliardenunlar--Dktktkturkeurt'])
# ('wrong: ', ['-verursacht-regen-in-kalifornien-a-000000.html                 ', '#-verursacht-regen-in-kalifornien-a-000000.html.               ', '\xc3\x9cbert-sachersaint-t-t-'])
# ('wrong: ', ['china-mehrere-tote-bei-explosion-auf-feuerwerkslaster-a-000000.html      ', '#china-mehrere-tote-bei-explosion-auf-feuerwerkslaster-a-000000.html.    ', 'chininMamarnere-e-lolon-loloeismonbrpion'])
# ('wrong: ', ['usend-kilometer-reichweite-a-000000.html                    ', '#usend-kilometer-reichweite-a-000000.html.                  ', 'kiusenDalotehrterrtenzteisisicheht'])
# ('wrong: ', ['china-mehrere-tote-bei-explosion-auf-feuerwerkslaster-a-000000.html      ', '#china-mehrere-tote-bei-explosion-auf-feuerwerkslaster-a-000000.html.    ', 'chininMamarnere-e-lolon-loloeismonbrpion'])
# ('wrong: ', ['-verursacht-regen-in-kalifornien-a-000000.html                 ', '#-verursacht-regen-in-kalifornien-a-000000.html.               ', '\xc3\x9cbert-sachersaint-t-t-'])
# ('wrong: ', ['-korrespondentin-ueber-attacke-auf-ard-team-a-000000.html           ', '#-korrespondentin-ueber-attacke-auf-ard-team-a-000000.html.         ', 'Inrerereonerreonerbronsvkrsmonololtm'])
# ('wrong: ', ['-hackerangriffe-wall-street-journal-ausgespaeht-a-000000.html         ', '#-hackerangriffe-wall-street-journal-ausgespaeht-a-000000.html.       ', 'Inkekengringringt-'])
# ('wrong: ', ['000-Milliarden-Dollar-Konjunkturpaket                     ', '#000-Milliarden-Dollar-Konjunkturpaket.                   ', '000-Milliardenunlar--Dktktkturkeurt'])
# ('wrong: ', ['-verursacht-regen-in-kalifornien-a-000000.html                 ', '#-verursacht-regen-in-kalifornien-a-000000.html.               ', '\xc3\x9cbert-sachersaint-t-t-'])
# ('wrong: ', ['-hackerangriffe-wall-street-journal-ausgespaeht-a-000000.html         ', '#-hackerangriffe-wall-street-journal-ausgespaeht-a-000000.html.       ', 'Inkekengringringt-'])
# ('wrong: ', ['usend-kilometer-reichweite-a-000000.html                    ', '#usend-kilometer-reichweite-a-000000.html.                  ', 'kiusenDalotehrterrtenzteisisicheht'])
# ('wrong: ', ['usend-kilometer-reichweite-a-000000.html                    ', '#usend-kilometer-reichweite-a-000000.html.                  ', 'kiusenDalotehrterrtenzteisisicheht'])
# ('wrong: ', ['000-Milliarden-Dollar-Konjunkturpaket                     ', '#000-Milliarden-Dollar-Konjunkturpaket.                   ', '000-Milliardenunlar--Dktktkturkeurt'])
# ('wrong: ', ['-verursacht-regen-in-kalifornien-a-000000.html                 ', '#-verursacht-regen-in-kalifornien-a-000000.html.               ', '\xc3\x9cbert-sachersaint-t-t-'])
# ('wrong: ', ['-hackerangriffe-wall-street-journal-ausgespaeht-a-000000.html         ', '#-hackerangriffe-wall-street-journal-ausgespaeht-a-000000.html.       ', 'Inkekengringringt-'])
# ('wrong: ', ['-hackerangriffe-wall-street-journal-ausgespaeht-a-000000.html         ', '#-hackerangriffe-wall-street-journal-ausgespaeht-a-000000.html.       ', 'Inkekengringringt-'])
# ('wrong: ', ['000-Milliarden-Dollar-Konjunkturpaket                     ', '#000-Milliarden-Dollar-Konjunkturpaket.                   ', '000-Milliardenunlar--Dktktkturkeurt'])
# ('wrong: ', ['-korrespondentin-ueber-attacke-auf-ard-team-a-000000.html           ', '#-korrespondentin-ueber-attacke-auf-ard-team-a-000000.html.         ', 'Inrerereonerreonerbronsvkrsmonololtm'])
# ('wrong: ', ['-hackerangriffe-wall-street-journal-ausgespaeht-a-000000.html         ', '#-hackerangriffe-wall-street-journal-ausgespaeht-a-000000.html.       ', 'Inkekengringringt-'])
# ('wrong: ', ['-verursacht-regen-in-kalifornien-a-000000.html                 ', '#-verursacht-regen-in-kalifornien-a-000000.html.               ', '\xc3\x9cbert-sachersaint-t-t-'])
# ('wrong: ', ['-hackerangriffe-wall-street-journal-ausgespaeht-a-000000.html         ', '#-hackerangriffe-wall-street-journal-ausgespaeht-a-000000.html.       ', 'Inkekengringringt-'])
# ('wrong: ', ['000-Milliarden-Dollar-Konjunkturpaket                     ', '#000-Milliarden-Dollar-Konjunkturpaket.                   ', '000-Milliardenunlar--Dktktkturkeurt'])
# ('wrong: ', ['000-Milliarden-Dollar-Konjunkturpaket                     ', '#000-Milliarden-Dollar-Konjunkturpaket.                   ', '000-Milliardenunlar--Dktktkturkeurt'])
# ('wrong: ', ['china-mehrere-tote-bei-explosion-auf-feuerwerkslaster-a-000000.html      ', '#china-mehrere-tote-bei-explosion-auf-feuerwerkslaster-a-000000.html.    ', 'chininMamarnere-e-lolon-loloeismonbrpion'])
# ('wrong: ', ['-hackerangriffe-wall-street-journal-ausgespaeht-a-000000.html         ', '#-hackerangriffe-wall-street-journal-ausgespaeht-a-000000.html.       ', 'Inkekengringringt-'])
# ('wrong: ', ['000-Milliarden-Dollar-Konjunkturpaket                     ', '#000-Milliarden-Dollar-Konjunkturpaket.                   ', '000-Milliardenunlar--Dktktkturkeurt'])
# 256 datas, accuracy 0.53516

# %%
print("#abc."[1:-1] == "abc")
# Out:
# True

# %%
print("/" in "http://www.spiegel.de/kultur/gesellschaft/china ")
# Out:
# True
