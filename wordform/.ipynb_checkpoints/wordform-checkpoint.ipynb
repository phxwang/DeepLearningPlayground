# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import os
import numpy as np
import random
import string
import tensorflow as tf
import zipfile
from six.moves import range
from six.moves.urllib.request import urlretrieve
from tensorflow.models.rnn.translate import seq2seq_model
import time
from os import listdir
from os.path import isfile, join
import codecs,re

# %%
sentence_pattern = "[\(|\)|\.|:|\?|;|!|,|\r|\n|\d|\s]+"

dfile = "./data/autobild_1_02_2013_0_decode.txt"
efile = "./data/autobild_1_02_2013_0_encode.txt"
def load_text_data(file_name):
    data = []
    with codecs.open(file_name,"r","latin-1") as f:
        d_text = "".join([l+" " for l in f.readlines()]).lower();
        for s in re.split(sentence_pattern,d_text):
            data.append(s)
    return data
#edata = load_text_data(efile)
#ddata = load_text_data(dfile)

#for e,d in zip(edata, ddata):
#    print(e, "", d)
    
def load_pair_data(file_name):
    data = []
    with codecs.open(file_name,"r","latin-1") as f:
        for l in f:
            data.append(re.split("[\r|\n|\s|\|]+",l)[::2])
    return data
#pair = load_pair_data("./data/autobild_1_02_2013_0_pair.txt")

def load_pair_data_from_dir(dir_path):
    pair = []
    for f in [join(dir_path, f) for f in listdir(dir_path) if isfile(join(dir_path, f))]:
        pair += load_pair_data(f)
    print("data loaded: ", len(pair))
    return pair

pair = load_pair_data_from_dir("/data/korpora/")
print(pair[:100])
# Out:
# data loaded:  15880543
# [[u'21'], [u'47', u''], [u'21', u''], [u'94', u''], [u'61', u''], [u'10', u''], [u'158', u''], [u'115', u'93'], [u'118'], [u'100', u''], [u'10', u''], [u'98', u'20', u'4'], [u'135', u''], [u'78', u''], [u'581', u'382'], [u'19', u''], [u'409', u'74', u'236', u''], [u'258', u''], [u'61', u'15', u'10', u''], [u'64', u'15', u'4'], [u'9'], [u'272', u'77'], [u'101', u'123', u'49', u''], [u'138', u'62', u''], [u'13'], [u'334', u''], [u'23', u'55', u'229'], [u'8'], [u'34', u'5'], [u'97', u'432', u'59'], [u'61', u''], [u'172', u'424', u''], [u'9'], [u'10', u''], [u'159', u'17', u''], [u'10', u''], [u'108', u''], [u'9'], [u'20', u''], [u'47', u''], [u'100', u'17', u'6'], [u'23', u'327', u''], [u'53', u''], [u'524', u'397'], [u'43'], [u'138', u'62', u''], [u'118'], [u'326', u'51'], [u'1148'], [u'295', u'49'], [u'477', u'369'], [u'43'], [u'591', u'254'], [u'118'], [u'274'], [u'21'], [u'100', u'13'], [u'72'], [u'505', u'254'], [u'43'], [u'21', u''], [u'530', u'8'], [u'373', u''], [u'38', u'5'], [u'16', u'4'], [u'297', u'41'], [u'43'], [u'16', u'37'], [u'68'], [u'75', u'6'], [u'9'], [u'468', u'30', u'31', u''], [u'172', u'8'], [u'10', u''], [u'128', u'25', u'4'], [u'1296', u'71'], [u'61', u''], [u'10', u''], [u'159', u'17', u''], [u'37', u'7'], [u'266', u'29'], [u'46'], [u'25', u'68', u'4'], [u'9'], [u'10', u''], [u'172', u'424'], [u'13'], [u'92', u'36'], [u'95', u'23', u'382', u'10'], [u'79', u'76'], [u'46'], [u'8', u'23', u''], [u'9'], [u'61', u''], [u'16', u'41'], [u'588', u'83', u''], [u'46'], [u'115', u'29', u''], [u'9'], [u'10', u'']]

# %%
reserved_letters = [' ','#','$','?',u'\xf6',u'\xe4',u'\xdf',u'\xfc',u'\xc4',u'\xd6',u'\xdc','-','.']
reserved_letters_len = len(reserved_letters)
EOF = reserved_letters.index('$')
UNK = reserved_letters.index('?')

vocabulary_size = len(string.ascii_lowercase)+ len(string.ascii_uppercase) + reserved_letters_len
lower_length = len(string.ascii_lowercase)
first_lower_letter = ord(string.ascii_lowercase[0])
first_upper_letter = ord(string.ascii_uppercase[0])

def char2id(char):
  if char in string.ascii_lowercase:
    return ord(char) - first_lower_letter + reserved_letters_len
  elif char in string.ascii_uppercase:
    return ord(char) - first_upper_letter + reserved_letters_len + lower_length
  try:
    id = reserved_letters.index(char)
    return id
  except:
    #print('Unexpected character: %s' % char)
    return UNK
  
def id2char(dictid):
  if dictid >= reserved_letters_len and dictid < reserved_letters_len + lower_length:
    return chr(dictid + first_lower_letter - reserved_letters_len)
  elif dictid >= reserved_letters_len + lower_length:
    return chr(dictid + first_upper_letter - reserved_letters_len - lower_length)
  elif dictid >= 0:
    return reserved_letters[dictid]
  else:
    return ' '

print(char2id('a'), char2id('z'), char2id(' '), char2id('ï'), char2id(u'\xf6'),char2id('Z'))
print(id2char(char2id('a')), id2char(26), id2char(0),id2char(char2id('B')))
# Out:
# 13 38 0 3 4 64
# a n   B
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:17: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal

# %%
_buckets = [(10, 10), (15, 15), (25, 25), (50, 50)]
def prepare_data(pair_data):
    data_set = [[] for _ in _buckets]
    for d in pair_data:
        if len(d) >= 2:
            s_id = [char2id(c) for c in d[0]]
            t_id = [char2id(c) for c in d[1]]
            t_id.append(EOF)
            for bucket_id, (source_size, target_size) in enumerate(_buckets):
              if len(s_id) < source_size and len(t_id) < target_size:
                if len(s_id)>0 and sum(s_id)/len(s_id) > UNK:
                    data_set[bucket_id].append([s_id, t_id])
                break
    return data_set

print(len(pair), "pairs")
valid_set_size = 100
valid_set = prepare_data(pair[:valid_set_size])
#train_set = prepare_data(pair[valid_set_size+1:])
for v in valid_set:
    print([["".join([id2char(c) for c in p]) for p in b] for b in v[:50]])
# Out:
# 15880543 pairs
# []
# []
# []
# []

# %%
num_nodes = 512
graph = tf.Graph()
batch_size = 64
with graph.as_default():
  model = seq2seq_model.Seq2SeqModel(source_vocab_size = vocabulary_size,
                                       target_vocab_size = vocabulary_size,
                                       buckets = _buckets,
                                       size = num_nodes,
                                       num_layers = 2, # one encoding and one decoding LSTM
                                       max_gradient_norm = 5.0,
                                       batch_size = batch_size,
                                       learning_rate = 1.0,
                                       learning_rate_decay_factor = 0.9,
                                       use_lstm = True,
                                       forward_only = False)

# %%
def evaluate_valid(bucket_id, printed_size):
    valid_batches = model.get_batch(valid_set, bucket_id) 
    _, eval_loss, output_logits = model.step(session, valid_batches[0], valid_batches[1],
                                       valid_batches[2], bucket_id, True)
    eval_ppx = np.exp(float(eval_loss)) if eval_loss < 300 else float(
              "inf")
    print("  eval perplexity: %.2f" % (eval_ppx))
    valid_input = np.transpose(valid_batches[0])
    valid_decode = np.transpose(valid_batches[1])
    for i in range(min(printed_size, len(valid_input))):
      outputs = [int(np.argmax(logit[i:i+1], axis=1)) for logit in output_logits]
      if EOF in outputs:
        outputs = outputs[0:outputs.index(EOF)]          
      print("  sampled valid (i,t,o)", "".join([id2char(o) for o in valid_input[i]])[::-1],"".join([id2char(o) for o in valid_decode[i]]),"".join([id2char(o) for o in outputs]))

# %%
num_steps = 20000
summary_frequency = 100
checkpoint_frequency = 1000
checkpoint_path = os.path.join("/data/checkpoints", "wordform.ckpt")

train_bucket_sizes = [len(train_set[b]) for b in xrange(len(_buckets))]
train_total_size = float(sum(train_bucket_sizes))
train_buckets_scale = [sum(train_bucket_sizes[:i + 1]) / train_total_size
                           for i in xrange(len(train_bucket_sizes))]


with tf.Session(graph=graph) as session:
  step_time = 0
  tf.initialize_all_variables().run()
  print('Initialized')
  mean_loss = 0
  previous_losses = []
  for step in range(num_steps):
    random_number_01 = np.random.random_sample()
    bucket_id = min([i for i in xrange(len(train_buckets_scale))
                       if train_buckets_scale[i] > random_number_01])
    
    e,d,w = model.get_batch(train_set, bucket_id)
    start_time = time.time()
    n,l,_ = model.step(session=session, encoder_inputs=e,decoder_inputs=d,target_weights=w,bucket_id=bucket_id,forward_only=False)
    mean_loss += l/summary_frequency
    step_time += (time.time() - start_time) / summary_frequency
    if (step+1) % checkpoint_frequency == 0:
      print("checkpoint...")
      model.saver.save(session, checkpoint_path, global_step=model.global_step)
    
    if (step+1) % summary_frequency == 0:
      # The mean loss is an estimate of the loss over the last few batches.
      perplexity = np.exp(float(mean_loss)) if mean_loss < 300 else float("inf")
      print ("global step %d learning rate %.4f step-time %.2f train perplexity "
               "%.2f" % (model.global_step.eval(), model.learning_rate.eval(),
                         step_time, perplexity))
      if len(previous_losses) > 2 and mean_loss > max(previous_losses[-3:]):
          print("run learning rate decay...")
          session.run(model.learning_rate_decay_op)
      previous_losses.append(mean_loss)
      mean_loss = 0
      step_time = 0
    
      evaluate_valid(bucket_id,20)
  print("Done.") 
  for b in xrange(len(_buckets)):
    evaluate_valid(b,batch_size)
# Out:
# Initialized
# global step 100 learning rate 1.0000 step-time 1.04 train perplexity 19.09
#   eval perplexity: 5.80
#   sampled valid (i,t,o) der        #d.        d
#   sampled valid (i,t,o) der        #d.        d
#   sampled valid (i,t,o) alles      #alle.     llll
#   sampled valid (i,t,o) weiß       #weiß.     ee
#   sampled valid (i,t,o) das        #d.        d
#   sampled valid (i,t,o) das        #d.        d
#   sampled valid (i,t,o) wie        #wie.      d
#   sampled valid (i,t,o) ist        #sein.     si
#   sampled valid (i,t,o) das        #d.        d
#   sampled valid (i,t,o) al-Duri    #al-Duri.  aaaa
#   sampled valid (i,t,o) An         #an.       n
#   sampled valid (i,t,o) war        #sein.     a
#   sampled valid (i,t,o) ist        #sein.     si
#   sampled valid (i,t,o) auf        #auf.      aa
#   sampled valid (i,t,o) Uhr        #Uhr.
#   sampled valid (i,t,o) York       #York.     oor
#   sampled valid (i,t,o) W.         #W..
#   sampled valid (i,t,o) records    #records.  rrrrrrrrrr
#   sampled valid (i,t,o) Boden      #Boden.    ddd
#   sampled valid (i,t,o) kurze      #kurz.     uurr
# global step 200 learning rate 1.0000 step-time 0.97 train perplexity 5.53
#   eval perplexity: 3.01
#   sampled valid (i,t,o) steht      #stehen.   seeeen
#   sampled valid (i,t,o) die        #d.        d
#   sampled valid (i,t,o) sich       #er.       er
#   sampled valid (i,t,o) Krieg      #Krieg.    Siiee
#   sampled valid (i,t,o) zweiten    #zweit.    weiin
#   sampled valid (i,t,o) glänzt     #glänzen.  gllnnnn
#   sampled valid (i,t,o) mit        #mit.      mit
#   sampled valid (i,t,o) sind       #sein.     siin
#   sampled valid (i,t,o) wie        #wie.      wii
#   sampled valid (i,t,o) einziges   #einzig.   iiiiggg
#   sampled valid (i,t,o) in         #in.       in
#   sampled valid (i,t,o) gesagt     #sagen.    gggene
#   sampled valid (i,t,o) ziehen     #ziehen.   eiei
#   sampled valid (i,t,o) darauf     #darauf.   daauf
#   sampled valid (i,t,o) zurück     #zurück.   zuuu
#   sampled valid (i,t,o) für        #für.      ffr
#   sampled valid (i,t,o) Kraft      #Kraft.    ürate
#   sampled valid (i,t,o) wischt     #wischen.  ssiienn
#   sampled valid (i,t,o) in         #in.       in
#   sampled valid (i,t,o) Blair      #Blair.    Baii
# global step 300 learning rate 1.0000 step-time 1.15 train perplexity 3.38
#   eval perplexity: 1.93
#   sampled valid (i,t,o) Fall       #Fall.     Ball
#   sampled valid (i,t,o) mit        #mit.      mit
#   sampled valid (i,t,o) mal        #mal.      aal
#   sampled valid (i,t,o) Moment     #Moment.   Momem
#   sampled valid (i,t,o) man        #man.      man
#   sampled valid (i,t,o) ist        #sein.     sein
#   sampled valid (i,t,o) Aber       #aber.     aber
#   sampled valid (i,t,o) Tag        #Tag.      Tag
#   sampled valid (i,t,o) sagt       #sagen.    sagen
#   sampled valid (i,t,o) Tage       #Tag.      Tage
#   sampled valid (i,t,o) Wand       #Wand.     waad
#   sampled valid (i,t,o) Pleuger    #Pleuger.  Aueueer
#   sampled valid (i,t,o) Falle      #Fall.     Falle
#   sampled valid (i,t,o) seinen     #sein.     sein
#   sampled valid (i,t,o) aus        #aus.      auss
#   sampled valid (i,t,o) steht      #stehen.   seehen
#   sampled valid (i,t,o) Mexiko     #Mexiko.   Beiioo
#   sampled valid (i,t,o) dem        #d.        d
#   sampled valid (i,t,o) dann       #dann.     dann
#   sampled valid (i,t,o) seines     #sein.     sein
# global step 400 learning rate 1.0000 step-time 1.11 train perplexity 3.29
#   eval perplexity: 1.63
#   sampled valid (i,t,o) Mehrheit   #Mehrheit. Uehreeih
#   sampled valid (i,t,o) links      #links.    kink
#   sampled valid (i,t,o) seine      #sein.     sein
#   sampled valid (i,t,o) im         #im.       im
#   sampled valid (i,t,o) Koffer     #Koffer.   ffffen
#   sampled valid (i,t,o) Blick      #Blick.    Bkikk
#   sampled valid (i,t,o) nicht      #nicht.    nicht
#   sampled valid (i,t,o) im         #im.       im
#   sampled valid (i,t,o) haben      #haben.    haben
#   sampled valid (i,t,o) nicht      #nicht.    nicht
#   sampled valid (i,t,o) Guineas    #Guinea.   Kuine
#   sampled valid (i,t,o) was        #was.      was
#   sampled valid (i,t,o) er         #er.       er
#   sampled valid (i,t,o) was        #was.      was
#   sampled valid (i,t,o) bin        #sein.     siin
#   sampled valid (i,t,o) eine       #ein.      ein
#   sampled valid (i,t,o) Fischer    #Fischer.  Mische
#   sampled valid (i,t,o) Lawrow     #Lawrow.   Hawwww
#   sampled valid (i,t,o) der        #d.        d
#   sampled valid (i,t,o) Museum     #Museum.   Kuueu
# global step 500 learning rate 1.0000 step-time 1.05 train perplexity 1.98
#   eval perplexity: 1.38
#   sampled valid (i,t,o) George     #George.   Gegrge
#   sampled valid (i,t,o) und        #und.      und
#   sampled valid (i,t,o) abnimmt    #abnehmen. annmmiin
#   sampled valid (i,t,o) kleinen    #klein.    klein
#   sampled valid (i,t,o) Warum      #warum.    Warum
#   sampled valid (i,t,o) warten     #warten.   sarten
#   sampled valid (i,t,o) die        #d.        d
#   sampled valid (i,t,o) Stimme     #Stimme.   Stimme
#   sampled valid (i,t,o) Block      #Block.    Boock
#   sampled valid (i,t,o) über       #über.     über
#   sampled valid (i,t,o) gibt       #geben.    geben
#   sampled valid (i,t,o) auch       #auch.     auch
#   sampled valid (i,t,o) sitzen     #sitzen.   setzen
#   sampled valid (i,t,o) silbernes  #silbern.  sileer
#   sampled valid (i,t,o) Fischer    #Fischer.  Miccher
#   sampled valid (i,t,o) Hans       #Hans.     Hans
#   sampled valid (i,t,o) ein        #ein.      ein
#   sampled valid (i,t,o) diesem     #dies.     dies
#   sampled valid (i,t,o) weniger    #weniger.  weniger
#   sampled valid (i,t,o) Krieg      #Krieg.    Frieg
# global step 600 learning rate 1.0000 step-time 1.05 train perplexity 1.75
#   eval perplexity: 1.19
#   sampled valid (i,t,o) Schuhen    #Schuh.    Schuhe
#   sampled valid (i,t,o) an         #an.       an
#   sampled valid (i,t,o) sich       #er.       er
#   sampled valid (i,t,o) Monat      #Monat.    Monat
#   sampled valid (i,t,o) als        #als.      als
#   sampled valid (i,t,o) in         #in.       in
#   sampled valid (i,t,o) keiner     #kein.     kein
#   sampled valid (i,t,o) im         #im.       im
#   sampled valid (i,t,o) lacht      #lachen.   lachtn
#   sampled valid (i,t,o) der        #d.        d
#   sampled valid (i,t,o) das        #d.        d
#   sampled valid (i,t,o) redet      #reden.    reden
#   sampled valid (i,t,o) der        #d.        d
#   sampled valid (i,t,o) Im         #im.       im
#   sampled valid (i,t,o) hat        #haben.    haben
#   sampled valid (i,t,o) selbst     #selbst.   selbee
#   sampled valid (i,t,o) man        #man.      man
#   sampled valid (i,t,o) Kameras    #Kamera.   Kaaaras
#   sampled valid (i,t,o) Stiege     #Stiege.   Stiege
#   sampled valid (i,t,o) von        #von.      von
# global step 700 learning rate 1.0000 step-time 1.10 train perplexity 1.56
#   eval perplexity: 1.25
#   sampled valid (i,t,o) Als        #als.      als
#   sampled valid (i,t,o) Mitte      #Mitte.    Mitte
#   sampled valid (i,t,o) hat        #haben.    haben
#   sampled valid (i,t,o) kann       #können.   können
#   sampled valid (i,t,o) de         #de.       d
#   sampled valid (i,t,o) Heute      #heute.    Heut
#   sampled valid (i,t,o) im         #im.       im
#   sampled valid (i,t,o) Geschäfte  #Geschäft. Geschäft
#   sampled valid (i,t,o) wohl       #wohl.     wohl
#   sampled valid (i,t,o) beginnt    #beginnen. bebennen
#   sampled valid (i,t,o) deutsche   #deutsch.  deutsch
#   sampled valid (i,t,o) ständige   #ständig.  ständig
#   sampled valid (i,t,o) werden     #werden.   werden
#   sampled valid (i,t,o) neue       #neu.      neu
#   sampled valid (i,t,o) setzen     #setzen.   setzen
#   sampled valid (i,t,o) Dollar     #Dollar.   Dollar
#   sampled valid (i,t,o) Der        #d.        d
#   sampled valid (i,t,o) de         #de.       d
#   sampled valid (i,t,o) -          #-.        -
#   sampled valid (i,t,o) bitten     #bitten.   bitten
# global step 800 learning rate 1.0000 step-time 1.04 train perplexity 1.38
#   eval perplexity: 1.33
#   sampled valid (i,t,o) zu         #zu.       zu
#   sampled valid (i,t,o) als        #als.      als
#   sampled valid (i,t,o) ihm        #er.       er
#   sampled valid (i,t,o) viel       #viel.     viel
#   sampled valid (i,t,o) Es         #es.       es
#   sampled valid (i,t,o) zwölf      #zwölf.    zoölfennnn
#   sampled valid (i,t,o) beharrt    #beharren. beharhen
#   sampled valid (i,t,o) Minister   #Minister. Miniseerii
#   sampled valid (i,t,o) Villepin   #Villepin. Hilleiil
#   sampled valid (i,t,o) River      #River.    Rieer
#   sampled valid (i,t,o) Nationen   #Nation.   Manion
#   sampled valid (i,t,o) hängt      #hängen.   haneen
#   sampled valid (i,t,o) und        #und.      und
#   sampled valid (i,t,o) ihm        #er.       er
#   sampled valid (i,t,o) die        #d.        d
#   sampled valid (i,t,o) nicht      #nicht.    nicht
#   sampled valid (i,t,o) worden     #werden.   werden
#   sampled valid (i,t,o) werden     #werden.   werden
#   sampled valid (i,t,o) Endspiel   #Endspiel. Enssiielii
#   sampled valid (i,t,o) lachen     #lachen.   lachen
# global step 900 learning rate 1.0000 step-time 1.24 train perplexity 1.45
#   eval perplexity: 1.15
#   sampled valid (i,t,o) ist        #sein.     sein
#   sampled valid (i,t,o) eine       #ein.      ein
#   sampled valid (i,t,o) meines     #mein.     mein
#   sampled valid (i,t,o) Als        #als.      als
#   sampled valid (i,t,o) vom        #vom.      vom
#   sampled valid (i,t,o) Seide      #Seide.    Seide
#   sampled valid (i,t,o) war        #sein.     sein
#   sampled valid (i,t,o) sollte     #sollen.   sollen
#   sampled valid (i,t,o) in         #in.       in
#   sampled valid (i,t,o) ist        #sein.     sein
#   sampled valid (i,t,o) einen      #ein.      ein
#   sampled valid (i,t,o) künftige   #künftig.  künftgg
#   sampled valid (i,t,o) ?Nein      #?Nein.    Neein
#   sampled valid (i,t,o) für        #für.      für
#   sampled valid (i,t,o) Größe      #Größe.    Größ
#   sampled valid (i,t,o) eine       #ein.      ein
#   sampled valid (i,t,o) Er         #er.       er
#   sampled valid (i,t,o) Wood       #Wood.     Wood
#   sampled valid (i,t,o) Er         #er.       er
#   sampled valid (i,t,o) Luft       #Luft.     Luft
# checkpoint...
# global step 1000 learning rate 1.0000 step-time 1.07 train perplexity 1.28
#   eval perplexity: 1.11
#   sampled valid (i,t,o) nächsten   #nah.      nahstttttt
#   sampled valid (i,t,o) vor        #vor.      vor
#   sampled valid (i,t,o) Saal       #Saal.     Saal
#   sampled valid (i,t,o) um         #um.       um
#   sampled valid (i,t,o) Doch       #doch.     doch
#   sampled valid (i,t,o) sich       #er.       er
#   sampled valid (i,t,o) an         #an.       an
#   sampled valid (i,t,o) das        #d.        d
#   sampled valid (i,t,o) Man        #man.      man
#   sampled valid (i,t,o) jüngstem   #jung.     jungsstttt
#   sampled valid (i,t,o) Staaten    #Staat.    Staat
#   sampled valid (i,t,o) nicht      #nicht.    nicht
#   sampled valid (i,t,o) großen     #groß.     groß
#   sampled valid (i,t,o) hat        #haben.    haben
#   sampled valid (i,t,o) eine       #ein.      ein
#   sampled valid (i,t,o) muss       #müssen.   müssen
#   sampled valid (i,t,o) er         #er.       er
#   sampled valid (i,t,o) zweite     #zweit.    zweit
#   sampled valid (i,t,o) sagen      #sagen.    sagen
#   sampled valid (i,t,o) Sitz       #Sitz.     Sitz
# global step 1100 learning rate 1.0000 step-time 0.97 train perplexity 1.15
#   eval perplexity: 1.12
#   sampled valid (i,t,o) weiß       #wissen.   wissen
#   sampled valid (i,t,o) als        #als.      als
#   sampled valid (i,t,o) seine      #sein.     sein
#   sampled valid (i,t,o) uns        #wir.      wir
#   sampled valid (i,t,o) sein       #sein.     sein
#   sampled valid (i,t,o) Kulisse    #Kulisse.  Kulisse
#   sampled valid (i,t,o) Antwort    #Antwort.  Antwort
#   sampled valid (i,t,o) er         #er.       er
#   sampled valid (i,t,o) er         #er.       er
#   sampled valid (i,t,o) vor        #vor.      vor
#   sampled valid (i,t,o) Moment     #Moment.   Moment
#   sampled valid (i,t,o) ist        #sein.     sein
#   sampled valid (i,t,o) alles      #alle.     alle
#   sampled valid (i,t,o) für        #für.      für
#   sampled valid (i,t,o) Sekretär   #Sekretär. Sekret
#   sampled valid (i,t,o) Doch       #doch.     doch
#   sampled valid (i,t,o) spielt     #spielen.  spielen
#   sampled valid (i,t,o) der        #d.        d
#   sampled valid (i,t,o) die        #d.        d
#   sampled valid (i,t,o) CNN-Frau   #CNN-Frau. NNN-rrau
# global step 1200 learning rate 1.0000 step-time 0.97 train perplexity 1.12
#   eval perplexity: 4.00
#   sampled valid (i,t,o) Sicherheitsrats           #Sicherheitsrat.          Sichhrtiits
#   sampled valid (i,t,o) Sicherheitsrat            #Sicherheitsrat.          Sicherbiits
#   sampled valid (i,t,o) Sicherheitsrat            #Sicherheitsrat.          Sicherbiits
#   sampled valid (i,t,o) Unglücklicherweise        #unglücklicherweise.      Ungüückiieeeiwiis
#   sampled valid (i,t,o) Uno-Resolution            #Uno-Resolution.          Uno-oououuiion
#   sampled valid (i,t,o) Afghanistan-Krieg         #Afghanistan-Krieg.       Aggaanistaiiiiieg
#   sampled valid (i,t,o) Sicherheitsrats           #Sicherheitsrat.          Sichhrtiits
#   sampled valid (i,t,o) Wandteppichversion        #Wandteppichversion.      Wandtepvisg
#   sampled valid (i,t,o) Verizon-Triband-Handy     #Verizon-Triband-Handy.   Verizonddddddnd
#   sampled valid (i,t,o) Intellektueller           #Intellektuelle.          Intelleueuel
#   sampled valid (i,t,o) Völkervertretern          #Völkervertretern.        Volkerventeete
#   sampled valid (i,t,o) Sicherheitsrats           #Sicherheitsrat.          Sichhrtiits
#   sampled valid (i,t,o) unaufgefordert            #unaufgefordert.          unafffedoddent
#   sampled valid (i,t,o) Ministerpräsident         #Ministerpräsident.       Ministeididdiden
#   sampled valid (i,t,o) heruntergekommenen        #heruntergekommen.        heruntemgomomeen
#   sampled valid (i,t,o) Feiertagsburnus           #Feiertagsburnus.         Feitrtauuuuuuds
#   sampled valid (i,t,o) Sicherheitsrat            #Sicherheitsrat.          Sicherbiits
#   sampled valid (i,t,o) Uno-Vertretung            #Uno-Vertretung.          Unootertuuuung
#   sampled valid (i,t,o) Uno-Botschafter           #Uno-Botschafter.         Unooootsohefeer
#   sampled valid (i,t,o) unabschätzbaren           #unabschätzbaren.         undbschabdeer
# global step 1300 learning rate 1.0000 step-time 0.99 train perplexity 1.12
#   eval perplexity: 1.05
#   sampled valid (i,t,o) im         #im.       im
#   sampled valid (i,t,o) sie        #sie.      sie
#   sampled valid (i,t,o) Momenten   #Moment.   Moment
#   sampled valid (i,t,o) zurück     #zurück.   zurück
#   sampled valid (i,t,o) einst      #einst.    einse
#   sampled valid (i,t,o) seinem     #sein.     sein
#   sampled valid (i,t,o) nach       #nach.     nach
#   sampled valid (i,t,o) Gesicht    #Gesicht.  Gesicht
#   sampled valid (i,t,o) von        #von.      von
#   sampled valid (i,t,o) mit        #mit.      mit
#   sampled valid (i,t,o) hier       #hier.     hier
#   sampled valid (i,t,o) seine      #sein.     sein
#   sampled valid (i,t,o) des        #d.        d
#   sampled valid (i,t,o) ist        #sein.     sein
#   sampled valid (i,t,o) Asche      #Asche.    asche
#   sampled valid (i,t,o) spricht    #sprechen. sprechen
#   sampled valid (i,t,o) von        #von.      von
#   sampled valid (i,t,o) aber       #aber.     aber
#   sampled valid (i,t,o) Munir      #Munir.    Munir
#   sampled valid (i,t,o) sagt       #sagen.    sagen
# global step 1400 learning rate 1.0000 step-time 1.07 train perplexity 1.13
#   eval perplexity: 1.11
#   sampled valid (i,t,o) ein        #ein.      ein
#   sampled valid (i,t,o) M-?        #M-?.      M-??
#   sampled valid (i,t,o) aufs       #aufs.     auf
#   sampled valid (i,t,o) spricht    #sprechen. sprechen
#   sampled valid (i,t,o) die        #d.        d
#   sampled valid (i,t,o) Frieden    #Frieden.  Frieden
#   sampled valid (i,t,o) Tricksen   #Tricksen. Trick
#   sampled valid (i,t,o) fühlt      #fühlen.   fühlen
#   sampled valid (i,t,o) Waffen     #Waffe.    Waffen
#   sampled valid (i,t,o) Stock      #Stock.    Stock
#   sampled valid (i,t,o) Als        #als.      als
#   sampled valid (i,t,o) zur        #zur.      zur
#   sampled valid (i,t,o) society    #society.  soittt
#   sampled valid (i,t,o) den        #d.        d
#   sampled valid (i,t,o) Personal   #Personal. Personal
#   sampled valid (i,t,o) ist        #sein.     sein
#   sampled valid (i,t,o) um         #um.       um
#   sampled valid (i,t,o) Telefons   #Telefon.  Telefonss
#   sampled valid (i,t,o) den        #d.        d
#   sampled valid (i,t,o) den        #d.        d
# global step 1500 learning rate 1.0000 step-time 1.10 train perplexity 1.12
#   eval perplexity: 1.08
#   sampled valid (i,t,o) Meldung    #Meldung.  Meldung
#   sampled valid (i,t,o) in         #in.       in
#   sampled valid (i,t,o) dort       #dort.     dort
#   sampled valid (i,t,o) ein        #ein.      ein
#   sampled valid (i,t,o) sieht      #sehen.    sehen
#   sampled valid (i,t,o) Versuch    #Versuch.  Versuch
#   sampled valid (i,t,o) Schräg     #schrägen. Schräg
#   sampled valid (i,t,o) dem        #d.        d
#   sampled valid (i,t,o) den        #d.        d
#   sampled valid (i,t,o) Vald?s     #Vald?s.   Valdss
#   sampled valid (i,t,o) den        #d.        d
#   sampled valid (i,t,o) auf        #auf.      auf
#   sampled valid (i,t,o) hat        #haben.    haben
#   sampled valid (i,t,o) oder       #oder.     oder
#   sampled valid (i,t,o) von        #von.      von
#   sampled valid (i,t,o) mit        #mit.      mit
#   sampled valid (i,t,o) den        #d.        d
#   sampled valid (i,t,o) Minister   #Minister. Minister
#   sampled valid (i,t,o) Uhr        #Uhr.      Uhr
#   sampled valid (i,t,o) der        #d.        d
# global step 1600 learning rate 1.0000 step-time 1.04 train perplexity 1.09
#   eval perplexity: 1.05
#   sampled valid (i,t,o) Irak       #Irak.     Irak
#   sampled valid (i,t,o) Saal       #Saal.     Saal
#   sampled valid (i,t,o) wie        #wie.      wie
#   sampled valid (i,t,o) auch       #auch.     auch
#   sampled valid (i,t,o) de         #de.       d
#   sampled valid (i,t,o) Sender     #Sender.   Sender
#   sampled valid (i,t,o) nicht      #nicht.    nicht
#   sampled valid (i,t,o) hätten     #haben.    haben
#   sampled valid (i,t,o) Um         #um.       um
#   sampled valid (i,t,o) Deutschen  #Deutsche. deutsch
#   sampled valid (i,t,o) laut       #laut.     laut
#   sampled valid (i,t,o) sind       #sein.     sein
#   sampled valid (i,t,o) ohne       #ohne.     ohne
#   sampled valid (i,t,o) die        #d.        d
#   sampled valid (i,t,o) nach       #nach.     nach
#   sampled valid (i,t,o) Rumsfeld   #Rumsfeld. Rumsfeld
#   sampled valid (i,t,o) Die        #d.        d
#   sampled valid (i,t,o) die        #d.        d
#   sampled valid (i,t,o) auf        #auf.      auf
#   sampled valid (i,t,o) Stadium    #Stadium.  Stadium
# global step 1700 learning rate 1.0000 step-time 1.08 train perplexity 1.20
# run learning rate decay...
#   eval perplexity: 1.04
#   sampled valid (i,t,o) Momenten   #Moment.   Momente
#   sampled valid (i,t,o) in         #in.       in
#   sampled valid (i,t,o) seit       #seit.     seit
#   sampled valid (i,t,o) Colin      #Colin.    Colin
#   sampled valid (i,t,o) Irak       #Irak.     Irak
#   sampled valid (i,t,o) Straße     #Straße.   Straße
#   sampled valid (i,t,o) über       #über.     über
#   sampled valid (i,t,o) zweite     #zweit.    zweit
#   sampled valid (i,t,o) ist        #sein.     sein
#   sampled valid (i,t,o) nach       #nach.     nach
#   sampled valid (i,t,o) sind       #sein.     sein
#   sampled valid (i,t,o) letzte     #letzt.    letzt
#   sampled valid (i,t,o) Die        #d.        d
#   sampled valid (i,t,o) globalen   #global.   global
#   sampled valid (i,t,o) Gesicht    #Gesicht.  Gesicht
#   sampled valid (i,t,o) Er         #er.       er
#   sampled valid (i,t,o) hört       #hören.    hören
#   sampled valid (i,t,o) oder       #oder.     oder
#   sampled valid (i,t,o) lebt       #leben.    leben
#   sampled valid (i,t,o) schon      #schon.    schon
# global step 1800 learning rate 0.9000 step-time 0.98 train perplexity 1.07
#   eval perplexity: 1.16
#   sampled valid (i,t,o) Negropontes     #Negropontes.   Negroponte
#   sampled valid (i,t,o) beteiligen      #beteiligen.    beteiligen
#   sampled valid (i,t,o) angeblich       #angeblich.     angeblich
#   sampled valid (i,t,o) konstruiert     #konstruieren.  konstruieren
#   sampled valid (i,t,o) Müllbeuteln     #Müllbeuteln.   Mülbbeuteln
#   sampled valid (i,t,o) schriftlichen   #schriftlich.   schrrftlich
#   sampled valid (i,t,o) friedliche      #friedlich.     friedlich
#   sampled valid (i,t,o) Folterung       #Folterung.     Folterung
#   sampled valid (i,t,o) Augenblicks     #Augenblicks.   Augenblick
#   sampled valid (i,t,o) Vorsitzende     #Vorsitzende.   Vorsitzend
#   sampled valid (i,t,o) Botschafter     #Botschafter.   Botschafter
#   sampled valid (i,t,o) Entscheidung    #Entscheidung.  Entscheidung
#   sampled valid (i,t,o) verlässt        #verlassen.     verlassen
#   sampled valid (i,t,o) Kopfhörer       #Kopfhörer.     Kopfhörer
#   sampled valid (i,t,o) abgeschotteten  #abgeschottet.  abseschotten
#   sampled valid (i,t,o) Forderung       #Forderung.     Forderung
#   sampled valid (i,t,o) weitergehen     #weitergehen.   weitergehen
#   sampled valid (i,t,o) Vielleicht      #vielleicht.    vielleicht
#   sampled valid (i,t,o) entschieden     #entscheiden.   entscheiden
#   sampled valid (i,t,o) ausgeräumt      #ausräumen.     aushäumen
# global step 1900 learning rate 0.9000 step-time 0.94 train perplexity 1.05
#   eval perplexity: 1.05
#   sampled valid (i,t,o) um         #um.       um
#   sampled valid (i,t,o) seine      #sein.     sein
#   sampled valid (i,t,o) Diplomat   #Diplomat. Diplomat
#   sampled valid (i,t,o) Es         #es.       es
#   sampled valid (i,t,o) lieber     #lieb.     liebeeeeee
#   sampled valid (i,t,o) er         #er.       er
#   sampled valid (i,t,o) Lunch      #Lunch.    Lunch
#   sampled valid (i,t,o) wie        #wie.      wie
#   sampled valid (i,t,o) konkret    #konkret.  konkret
#   sampled valid (i,t,o) erzählt    #erzählen. erzählen
#   sampled valid (i,t,o) sich       #er.       er
#   sampled valid (i,t,o) im         #im.       im
#   sampled valid (i,t,o) Er         #er.       er
#   sampled valid (i,t,o) jemand     #jemand.   jemand
#   sampled valid (i,t,o) nicht      #nicht.    nicht
#   sampled valid (i,t,o) als        #als.      als
#   sampled valid (i,t,o) den        #d.        d
#   sampled valid (i,t,o) Blufft     #Blufft.   Blufft
#   sampled valid (i,t,o) dieser     #dies.     dies
#   sampled valid (i,t,o) im         #im.       im
# checkpoint...
# global step 2000 learning rate 0.9000 step-time 1.05 train perplexity 1.07
#   eval perplexity: 1.04
#   sampled valid (i,t,o) alle       #alle.     alle
#   sampled valid (i,t,o) seit       #seit.     seit
#   sampled valid (i,t,o) aus        #aus.      aus
#   sampled valid (i,t,o) kein       #kein.     kein
#   sampled valid (i,t,o) Gabriel    #Gabriel.  Gabriel
#   sampled valid (i,t,o) Runde      #Runde.    Runde
#   sampled valid (i,t,o) Wirklich   #wirklich. Wirklich
#   sampled valid (i,t,o) den        #d.        d
#   sampled valid (i,t,o) andere     #ander.    ander
#   sampled valid (i,t,o) die        #d.        d
#   sampled valid (i,t,o) Blix       #Blix.     Blix
#   sampled valid (i,t,o) er         #er.       er
#   sampled valid (i,t,o) Man        #man.      man
#   sampled valid (i,t,o) von        #von.      von
#   sampled valid (i,t,o) im         #im.       im
#   sampled valid (i,t,o) kleinen    #klein.    klein
#   sampled valid (i,t,o) Kunst      #Kunst.    Kunst
#   sampled valid (i,t,o) Beweis     #Beweis.   Beweis
#   sampled valid (i,t,o) USA        #USA.      USA
#   sampled valid (i,t,o) Republik   #Republik. Republik
# global step 2100 learning rate 0.9000 step-time 0.99 train perplexity 1.05
#   eval perplexity: 1.03
#   sampled valid (i,t,o) feucht     #feucht.   feucht
#   sampled valid (i,t,o) Rede       #Rede.     Rede
#   sampled valid (i,t,o) guter      #gut.      gut
#   sampled valid (i,t,o) was        #was.      was
#   sampled valid (i,t,o) auf        #auf.      auf
#   sampled valid (i,t,o) gefangen   #fangen.   fingen
#   sampled valid (i,t,o) farbige    #farbig.   farbig
#   sampled valid (i,t,o) fast       #fast.     fast
#   sampled valid (i,t,o) Irak       #Irak.     Irak
#   sampled valid (i,t,o) Krieg      #Krieg.    Krieg
#   sampled valid (i,t,o) Hussein    #Hussein.  Hussein
#   sampled valid (i,t,o) Ich        #ich.      ich
#   sampled valid (i,t,o) von        #von.      von
#   sampled valid (i,t,o) wenn       #wenn.     wenn
#   sampled valid (i,t,o) Blix       #Blix.     Blix
#   sampled valid (i,t,o) den        #d.        d
#   sampled valid (i,t,o) stehen     #stehen.   stehen
#   sampled valid (i,t,o) Vor        #vor.      vor
#   sampled valid (i,t,o) er         #er.       er
#   sampled valid (i,t,o) ihm        #er.       er
# global step 2200 learning rate 0.9000 step-time 1.00 train perplexity 1.05
#   eval perplexity: 1.02
#   sampled valid (i,t,o) uns        #wir.      wir
#   sampled valid (i,t,o) sein       #sein.     sein
#   sampled valid (i,t,o) zu         #zu.       zu
#   sampled valid (i,t,o) eine       #ein.      ein
#   sampled valid (i,t,o) die        #d.        d
#   sampled valid (i,t,o) sein       #sein.     sein
#   sampled valid (i,t,o) erste      #erst.     erst
#   sampled valid (i,t,o) dass       #dass.     dass
#   sampled valid (i,t,o) sich       #er.       er
#   sampled valid (i,t,o) dass       #dass.     dass
#   sampled valid (i,t,o) Käse       #Käse.     Kase
#   sampled valid (i,t,o) den        #d.        d
#   sampled valid (i,t,o) sagt       #sagen.    sagen
#   sampled valid (i,t,o) mit        #mit.      mit
#   sampled valid (i,t,o) den        #d.        d
#   sampled valid (i,t,o) sein       #sein.     sein
#   sampled valid (i,t,o) der        #d.        d
#   sampled valid (i,t,o) oder       #oder.     oder
#   sampled valid (i,t,o) seinem     #sein.     sein
#   sampled valid (i,t,o) al-Duri    #al-Duri.  al-Duri
# global step 2300 learning rate 0.9000 step-time 0.99 train perplexity 1.04
#   eval perplexity: 1.03
#   sampled valid (i,t,o) bereits    #bereits.  bereits
#   sampled valid (i,t,o) lacht      #lachen.   lachen
#   sampled valid (i,t,o) in         #in.       in
#   sampled valid (i,t,o) Nein       #nein.     nein
#   sampled valid (i,t,o) die        #d.        d
#   sampled valid (i,t,o) Blix       #Blix.     Blix
#   sampled valid (i,t,o) Woche      #Woche.    Woche
#   sampled valid (i,t,o) seit       #seit.     seit
#   sampled valid (i,t,o) Saddam     #Saddam.   Saddam
#   sampled valid (i,t,o) ein        #ein.      ein
#   sampled valid (i,t,o) meines     #mein.     mein
#   sampled valid (i,t,o) an         #an.       an
#   sampled valid (i,t,o) im         #im.       im
#   sampled valid (i,t,o) der        #d.        d
#   sampled valid (i,t,o) und        #und.      und
#   sampled valid (i,t,o) er         #er.       er
#   sampled valid (i,t,o) Dienstag   #Dienstag. Dienstag
#   sampled valid (i,t,o) dieser     #dies.     dies
#   sampled valid (i,t,o) die        #d.        d
#   sampled valid (i,t,o) auf        #auf.      auf
# global step 2400 learning rate 0.9000 step-time 1.02 train perplexity 1.05
#   eval perplexity: 1.13
#   sampled valid (i,t,o) quadratischen   #quadratisch.   juddratisch
#   sampled valid (i,t,o) Manuskript      #Manuskript.    Manuskript
#   sampled valid (i,t,o) schiefergrau    #schiefergrau.  schiefergrau
#   sampled valid (i,t,o) Milliarden      #Milliarde.     Milliarde
#   sampled valid (i,t,o) erreichbar      #erreichbar.    erreichbar
#   sampled valid (i,t,o) etablierten     #etablieren.    etablieren
#   sampled valid (i,t,o) Gebetskette     #Gebetskette.   Gebetskette
#   sampled valid (i,t,o) europäischer    #europäisch.    europäisch
#   sampled valid (i,t,o) Fensterlos      #Fensterlos.    Fensterlos
#   sampled valid (i,t,o) Beschwört       #beschwören.    Beschwörtn
#   sampled valid (i,t,o) verschossenen   #verschossen.   verschissen
#   sampled valid (i,t,o) Verantwortung   #Verantwortung. Verantwortung
#   sampled valid (i,t,o) abhörsicheren   #abhörsicher.   abhörsich
#   sampled valid (i,t,o) Fiedler?s       #Fiedler?s.     Fiedler?s
#   sampled valid (i,t,o) beschlossen     #beschließen.   beschließen
#   sampled valid (i,t,o) Discjockey      #Discjockey.    Discoocke
#   sampled valid (i,t,o) Vertreter       #Vertreter.     Vertreter
#   sampled valid (i,t,o) Washington      #Washington.    Washington
#   sampled valid (i,t,o) Industriepark   #Industriepark. Industriepark
#   sampled valid (i,t,o) dreifachem      #dreifach.      dreifach
# global step 2500 learning rate 0.9000 step-time 1.02 train perplexity 1.04
#   eval perplexity: 1.05
#   sampled valid (i,t,o) Aber       #aber.     aber
#   sampled valid (i,t,o) Sehr       #sehr.     sehr
#   sampled valid (i,t,o) Käse       #Käse.     Kase
#   sampled valid (i,t,o) Flur       #Flur.     Flur
#   sampled valid (i,t,o) Käppchen   #Käppchen. Käppche
#   sampled valid (i,t,o) New        #New.      New
#   sampled valid (i,t,o) hat        #haben.    haben
#   sampled valid (i,t,o) jetzt      #jetzt.    jetzt
#   sampled valid (i,t,o) Am         #am.       am
#   sampled valid (i,t,o) Regeln     #Regel.    Regel
#   sampled valid (i,t,o) die        #d.        d
#   sampled valid (i,t,o) Sitzung    #Sitzung.  Sitzung
#   sampled valid (i,t,o) Halb       #halb.     halb
#   sampled valid (i,t,o) Angola     #Angola.   Angola
#   sampled valid (i,t,o) Saddam     #Saddam.   Saddam
#   sampled valid (i,t,o) bevor      #bevor.    bevor
#   sampled valid (i,t,o) mit        #mit.      mit
#   sampled valid (i,t,o) Schrecken  #Schreck.  schreck
#   sampled valid (i,t,o) in         #in.       in
#   sampled valid (i,t,o) zwölf      #zwölf.    zwölf
# global step 2600 learning rate 0.9000 step-time 0.98 train perplexity 1.04
#   eval perplexity: 1.03
#   sampled valid (i,t,o) Hat        #haben.    haben
#   sampled valid (i,t,o) hat        #haben.    haben
#   sampled valid (i,t,o) kann       #können.   können
#   sampled valid (i,t,o) nur        #nur.      nur
#   sampled valid (i,t,o) Scharfe    #scharf.   Scharfeeee
#   sampled valid (i,t,o) kann       #können.   können
#   sampled valid (i,t,o) Es         #es.       es
#   sampled valid (i,t,o) eifrig     #eifrig.   eifrig
#   sampled valid (i,t,o) sind       #sein.     sein
#   sampled valid (i,t,o) Minister   #Minister. Minister
#   sampled valid (i,t,o) denen      #d.        d
#   sampled valid (i,t,o) Kisten     #Kiste.    Kisten
#   sampled valid (i,t,o) zwischen   #zwischen. zwischen
#   sampled valid (i,t,o) alte       #alt.      alt
#   sampled valid (i,t,o) dem        #d.        d
#   sampled valid (i,t,o) nur        #nur.      nur
#   sampled valid (i,t,o) etwas      #etwas.    etwas
#   sampled valid (i,t,o) am         #am.       am
#   sampled valid (i,t,o) Herzen     #Herz.     Herz
#   sampled valid (i,t,o) Auch       #auch.     auch
# global step 2700 learning rate 0.9000 step-time 1.03 train perplexity 1.04
#   eval perplexity: 1.05
#   sampled valid (i,t,o) steckt     #stecken.  stecken
#   sampled valid (i,t,o) Schröder   #Schröder. Schröder
#   sampled valid (i,t,o) die        #d.        d
#   sampled valid (i,t,o) der        #d.        d
#   sampled valid (i,t,o) der        #d.        d
#   sampled valid (i,t,o) in         #in.       in
#   sampled valid (i,t,o) Traor?     #Traor?.   Traor?
#   sampled valid (i,t,o) gut        #gut.      gut
#   sampled valid (i,t,o) Ernst      #Ernst.    Ernst
#   sampled valid (i,t,o) geben      #geben.    geben
#   sampled valid (i,t,o) heißt      #heißen.   heißen
#   sampled valid (i,t,o) sah        #sehen.    sehen
#   sampled valid (i,t,o) das        #d.        d
#   sampled valid (i,t,o) die        #d.        d
#   sampled valid (i,t,o) die        #d.        d
#   sampled valid (i,t,o) Drehtür    #Drehtür.  Drehtür
#   sampled valid (i,t,o) liest      #lesen.    lesen
#   sampled valid (i,t,o) Stimme     #Stimme.   Stimme
#   sampled valid (i,t,o) von        #von.      von
#   sampled valid (i,t,o) Stimme     #Stimme.   Stimme
# global step 2800 learning rate 0.9000 step-time 0.97 train perplexity 1.04
#   eval perplexity: 1.02
#   sampled valid (i,t,o) sich       #er.       er
#   sampled valid (i,t,o) Gunter     #Gunter.   Gunter
#   sampled valid (i,t,o) am         #am.       am
#   sampled valid (i,t,o) die        #d.        d
#   sampled valid (i,t,o) soll       #sollen.   sollen
#   sampled valid (i,t,o) Die        #d.        d
#   sampled valid (i,t,o) Partner    #Partner.  Partner
#   sampled valid (i,t,o) ist        #sein.     sein
#   sampled valid (i,t,o) fixieren   #fixieren. fixier
#   sampled valid (i,t,o) Abend      #Abend.    Abend
#   sampled valid (i,t,o) Guinea     #Guinea.   Guinea
#   sampled valid (i,t,o) zu         #zu.       zu
#   sampled valid (i,t,o) zum        #zum.      zum
#   sampled valid (i,t,o) halten     #halten.   halten
#   sampled valid (i,t,o) eine       #ein.      ein
#   sampled valid (i,t,o) nicht      #nicht.    nicht
#   sampled valid (i,t,o) Colin      #Colin.    Colin
#   sampled valid (i,t,o) er         #er.       er
#   sampled valid (i,t,o) Wodka      #Wodka.    Wodka
#   sampled valid (i,t,o) saves      #saves.    saven
# global step 2900 learning rate 0.9000 step-time 1.05 train perplexity 1.04
#   eval perplexity: 1.04
#   sampled valid (i,t,o) führt      #führen.   führen
#   sampled valid (i,t,o) die        #d.        d
#   sampled valid (i,t,o) draußen    #draußen.  draußen
#   sampled valid (i,t,o) Zypern     #Zypern.   Zypern
#   sampled valid (i,t,o) Täuschen   #Täuschen. Täusche
#   sampled valid (i,t,o) zwischen   #zwischen. zwischen
#   sampled valid (i,t,o) meine      #mein.     mein
#   sampled valid (i,t,o) eine       #ein.      ein
#   sampled valid (i,t,o) steht      #stehen.   stehen
#   sampled valid (i,t,o) kaufen     #kaufen.   kaufen
#   sampled valid (i,t,o) über       #über.     über
#   sampled valid (i,t,o) im         #im.       im
#   sampled valid (i,t,o) seltenem   #selten.   selten
#   sampled valid (i,t,o) manchmal   #manchmal. manchmal
#   sampled valid (i,t,o) die        #d.        d
#   sampled valid (i,t,o) durch      #durch.    durch
#   sampled valid (i,t,o) dass       #dass.     dass
#   sampled valid (i,t,o) schneller  #schnell.  schnell
#   sampled valid (i,t,o) Seide      #Seide.    Seide
#   sampled valid (i,t,o) glänzt     #glänzen.  glänzen
# checkpoint...
# global step 3000 learning rate 0.9000 step-time 1.09 train perplexity 1.22
# run learning rate decay...
#   eval perplexity: 1.05
#   sampled valid (i,t,o) Text       #Text.     Text
#   sampled valid (i,t,o) Satz       #Satz.     Satz
#   sampled valid (i,t,o) fünf       #fünf.     fünf
#   sampled valid (i,t,o) John       #John.     John
#   sampled valid (i,t,o) Saddams    #Saddam.   Saddamssss
#   sampled valid (i,t,o) viel       #viel.     viel
#   sampled valid (i,t,o) anderem    #ander.    ander
#   sampled valid (i,t,o) Le         #Le.       Le
#   sampled valid (i,t,o) Colin      #Colin.    Colin
#   sampled valid (i,t,o) Am         #am.       am
#   sampled valid (i,t,o) Nach       #nach.     nach
#   sampled valid (i,t,o) Telefonen  #Telefon.  Telefon
#   sampled valid (i,t,o) geht       #gehen.    gehen
#   sampled valid (i,t,o) heißt      #heißen.   heißen
#   sampled valid (i,t,o) Jena       #Jena.     Jena
#   sampled valid (i,t,o) russische  #russisch. russisch
#   sampled valid (i,t,o) Fasten     #Fasten.   Faste
#   sampled valid (i,t,o) wird       #werden.   werden
#   sampled valid (i,t,o) zu         #zu.       zu
#   sampled valid (i,t,o) in         #in.       in
# global step 3100 learning rate 0.8100 step-time 0.95 train perplexity 1.05
#   eval perplexity: 1.03
#   sampled valid (i,t,o) es         #es.       es
#   sampled valid (i,t,o) einen      #ein.      ein
#   sampled valid (i,t,o) räumen     #räumen.   raumen
#   sampled valid (i,t,o) nach       #nach.     nach
#   sampled valid (i,t,o) sich       #er.       er
#   sampled valid (i,t,o) die        #d.        d
#   sampled valid (i,t,o) Summe      #Summe.    Summe
#   sampled valid (i,t,o) anderen    #ander.    ander
#   sampled valid (i,t,o) ohne       #ohne.     ohne
#   sampled valid (i,t,o) soll       #sollen.   sollen
#   sampled valid (i,t,o) wollen     #wollen.   wollen
#   sampled valid (i,t,o) für        #für.      für
#   sampled valid (i,t,o) Powell     #Powell.   Powell
#   sampled valid (i,t,o) Osama      #Osama.    Osama
#   sampled valid (i,t,o) noch       #noch.     noch
#   sampled valid (i,t,o) nicht      #nicht.    nicht
#   sampled valid (i,t,o) über       #über.     über
#   sampled valid (i,t,o) an         #an.       an
#   sampled valid (i,t,o) auch       #auch.     auch
#   sampled valid (i,t,o) er         #er.       er
# global step 3200 learning rate 0.8100 step-time 1.06 train perplexity 1.05
#   eval perplexity: 1.02
#   sampled valid (i,t,o) am         #am.       am
#   sampled valid (i,t,o) die        #d.        d
#   sampled valid (i,t,o) ja         #ja.       ja
#   sampled valid (i,t,o) viel       #viel.     viel
#   sampled valid (i,t,o) waren      #sein.     sein
#   sampled valid (i,t,o) kleine     #klein.    klein
#   sampled valid (i,t,o) Was        #was.      was
#   sampled valid (i,t,o) sich       #er.       er
#   sampled valid (i,t,o) die        #d.        d
#   sampled valid (i,t,o) Kollegen   #Kollege.  Kollege
#   sampled valid (i,t,o) Der        #d.        d
#   sampled valid (i,t,o) Saal       #Saal.     Saal
#   sampled valid (i,t,o) der        #d.        d
#   sampled valid (i,t,o) Igor       #Igor.     Igor
#   sampled valid (i,t,o) nur        #nur.      nur
#   sampled valid (i,t,o) Dann       #dann.     dann
#   sampled valid (i,t,o) diesmal    #diesmal.  diesmal
#   sampled valid (i,t,o) Powell     #Powell.   Powell
#   sampled valid (i,t,o) Hussein    #Hussein.  Hussein
#   sampled valid (i,t,o) er         #er.       er
# global step 3300 learning rate 0.8100 step-time 0.96 train perplexity 1.03
#   eval perplexity: 1.05
#   sampled valid (i,t,o) Frieden    #Frieden.  Frieden
#   sampled valid (i,t,o) die        #d.        d
#   sampled valid (i,t,o) im         #im.       im
#   sampled valid (i,t,o) mit        #mit.      mit
#   sampled valid (i,t,o) von        #von.      von
#   sampled valid (i,t,o) seines     #sein.     sein
#   sampled valid (i,t,o) Hans       #Hans.     Hans
#   sampled valid (i,t,o) mir        #ich.      ich
#   sampled valid (i,t,o) noch       #noch.     noch
#   sampled valid (i,t,o) ist        #sein.     sein
#   sampled valid (i,t,o) es         #es.       es
#   sampled valid (i,t,o) M-?        #M-?.      M-??
#   sampled valid (i,t,o) kein       #kein.     kein
#   sampled valid (i,t,o) im         #im.       im
#   sampled valid (i,t,o) uns        #wir.      wir
#   sampled valid (i,t,o) die        #d.        d
#   sampled valid (i,t,o) Türen      #Tür.      Türeeeeeee
#   sampled valid (i,t,o) Gruppen    #Gruppe.   Gruppe
#   sampled valid (i,t,o) Erklärt    #erklären. Erklären
#   sampled valid (i,t,o) Aber       #Aber.     aber
# global step 3400 learning rate 0.8100 step-time 1.04 train perplexity 1.04
#   eval perplexity: 1.17
#   sampled valid (i,t,o) Oktoberfest-Bier          #Oktoberfest-Bier.        Oktoberfest-Bier
#   sampled valid (i,t,o) Pressekonferenz           #Pressekonferenz.         Pressekonferenz
#   sampled valid (i,t,o) Zusammenarbeit            #Zusammenarbeit.          Zusammenarbeit
#   sampled valid (i,t,o) US-Außenminister          #US-Außenminister.        US-AuSenminister
#   sampled valid (i,t,o) Übertragungswagen         #Übertragungswagen.       Übertragungssagen
#   sampled valid (i,t,o) Aschermittwoch            #Aschermittwoch.          Aschermittwoch
#   sampled valid (i,t,o) Kriegsresolution          #Kriegsresolution.        Kriggsresolution
#   sampled valid (i,t,o) Uno-Sicherheitsrats       #Uno-Sicherheitsrats.     Uno-Sicherheitsrats
#   sampled valid (i,t,o) Handelskontakte           #Handelskontakt.          Handelskontakteeeeetteeee
#   sampled valid (i,t,o) Alternativ-Resolution     #Alternativ-Resolution.   Alternati--eesolution
#   sampled valid (i,t,o) Großbritannien            #Großbritannien.          Großbritannien
#   sampled valid (i,t,o) Biowaffen-Bomben          #Biowaffen-Bomben.        Biowaffen-Bomben
#   sampled valid (i,t,o) zusammensitzt             #zusammensitzen.          zusammensitzen
#   sampled valid (i,t,o) Mikrofonständer           #Mikrofonständer.         Mikrofonständer
#   sampled valid (i,t,o) Quartalsbericht           #Quartalsbericht.         Quartalsbericht
#   sampled valid (i,t,o) ??-Jahres-Tief            #??-Jahres-Tief.          ???Jarres-Tief
#   sampled valid (i,t,o) Waffenkontrollen          #Waffenkontrolle.         Waffenkontrollen
#   sampled valid (i,t,o) Sicherheitsrats           #Sicherheitsrat.          Sicherheitsrats
#   sampled valid (i,t,o) Herausforderung           #Herausforderung.         Herausforderung
#   sampled valid (i,t,o) Großbritannien            #Großbritannien.          Großbritannien
# global step 3500 learning rate 0.8100 step-time 1.06 train perplexity 1.03
#   eval perplexity: 1.03
#   sampled valid (i,t,o) weißem     #weiß.     wiiß
#   sampled valid (i,t,o) Ordnung    #Ordnung.  Ordnung
#   sampled valid (i,t,o) Halb       #halb.     Halb
#   sampled valid (i,t,o) Herzen     #Herz.     Herz
#   sampled valid (i,t,o) Traor?     #Traor?.   Traor?
#   sampled valid (i,t,o) ist        #sein.     sein
#   sampled valid (i,t,o) es         #es.       es
#   sampled valid (i,t,o) muss       #müssen.   müssen
#   sampled valid (i,t,o) Hof        #Hof.      Hof
#   sampled valid (i,t,o) braucht    #brauchen. brauchen
#   sampled valid (i,t,o) aufs       #aufs.     aufs
#   sampled valid (i,t,o) Zeit       #Zeit.     Zeit
#   sampled valid (i,t,o) weil       #weil.     weil
#   sampled valid (i,t,o) Beweise    #Beweis.   Beweiseeee
#   sampled valid (i,t,o) nennen     #nennen.   nennen
#   sampled valid (i,t,o) in         #in.       in
#   sampled valid (i,t,o) Sabli?re   #Sabli?re. Sabli?re
#   sampled valid (i,t,o) ob         #ob.       ob
#   sampled valid (i,t,o) oder       #oder.     oder
#   sampled valid (i,t,o) spürt      #spüren.   spüren
# global step 3600 learning rate 0.8100 step-time 0.93 train perplexity 1.02
#   eval perplexity: 1.02
#   sampled valid (i,t,o) Welt       #Welt.     Welt
#   sampled valid (i,t,o) der        #d.        d
#   sampled valid (i,t,o) Bombe      #Bombe.    Bombe
#   sampled valid (i,t,o) davon      #davon.    davon
#   sampled valid (i,t,o) der        #d.        d
#   sampled valid (i,t,o) der        #d.        d
#   sampled valid (i,t,o) Fischer    #Fischer.  Fisch
#   sampled valid (i,t,o) im         #im.       im
#   sampled valid (i,t,o) zum        #zum.      zum
#   sampled valid (i,t,o) sind       #sein.     sein
#   sampled valid (i,t,o) in         #in.       in
#   sampled valid (i,t,o) Auch       #auch.     auch
#   sampled valid (i,t,o) vom        #vom.      vom
#   sampled valid (i,t,o) würden     #werden.   werden
#   sampled valid (i,t,o) ein        #ein.      ein
#   sampled valid (i,t,o) gewesen    #sein.     sein
#   sampled valid (i,t,o) so         #so.       so
#   sampled valid (i,t,o) Gesicht    #Gesicht.  Gesicht
#   sampled valid (i,t,o) wurde      #werden.   werden
#   sampled valid (i,t,o) folgt      #folgen.   folgen
# global step 3700 learning rate 0.8100 step-time 1.05 train perplexity 1.03
#   eval perplexity: 1.02
#   sampled valid (i,t,o) Gute       #Gut.      gut
#   sampled valid (i,t,o) Woche      #Woche.    Woche
#   sampled valid (i,t,o) dass       #dass.     dass
#   sampled valid (i,t,o) der        #d.        d
#   sampled valid (i,t,o) mit        #mit.      mit
#   sampled valid (i,t,o) der        #d.        d
#   sampled valid (i,t,o) Irak       #Irak.     Irak
#   sampled valid (i,t,o) die        #d.        d
#   sampled valid (i,t,o) Gesicht    #Gesicht.  Gesicht
#   sampled valid (i,t,o) sie        #sie.      sie
#   sampled valid (i,t,o) sagen      #sagen.    sagen
#   sampled valid (i,t,o) Beweise    #Beweis.   Beweiseeee
#   sampled valid (i,t,o) seiner     #sein.     sein
#   sampled valid (i,t,o) Welcome    #Welcome.  Welcome
#   sampled valid (i,t,o) Wenn       #wenn.     wenn
#   sampled valid (i,t,o) ein        #ein.      ein
#   sampled valid (i,t,o) Uhr        #Uhr.      Uhr
#   sampled valid (i,t,o) es         #es.       es
#   sampled valid (i,t,o) sich       #er.       er
#   sampled valid (i,t,o) einen      #ein.      ein
# global step 3800 learning rate 0.8100 step-time 1.03 train perplexity 1.03
#   eval perplexity: 1.02
#   sampled valid (i,t,o) Es         #es.       es
#   sampled valid (i,t,o) ein        #ein.      ein
#   sampled valid (i,t,o) der        #d.        d
#   sampled valid (i,t,o) den        #d.        d
#   sampled valid (i,t,o) dann       #dann.     dann
#   sampled valid (i,t,o) seine      #sein.     sein
#   sampled valid (i,t,o) Fischer    #Fischer.  Fisch
#   sampled valid (i,t,o) die        #d.        d
#   sampled valid (i,t,o) ihn        #er.       er
#   sampled valid (i,t,o) Herr       #Herr.     Herr
#   sampled valid (i,t,o) Spanien    #Spanien.  Spanien
#   sampled valid (i,t,o) wird       #werden.   werden
#   sampled valid (i,t,o) der        #d.        d
#   sampled valid (i,t,o) den        #d.        d
#   sampled valid (i,t,o) das        #d.        d
#   sampled valid (i,t,o) grünem     #grün.     grün
#   sampled valid (i,t,o) Ich        #ich.      ich
#   sampled valid (i,t,o) wie        #wie.      wie
#   sampled valid (i,t,o) wird       #werden.   werden
#   sampled valid (i,t,o) Summen     #Summe.    Summen
# global step 3900 learning rate 0.8100 step-time 0.99 train perplexity 1.03
#   eval perplexity: 1.09
#   sampled valid (i,t,o) angegriffen     #angreifen.     angriifen
#   sampled valid (i,t,o) inzwischen      #inzwischen.    inzwischen
#   sampled valid (i,t,o) Uno-Gebäudes    #Uno-Gebäudes.  Uno-Gebäudes
#   sampled valid (i,t,o) europäischen    #europäisch.    europäisch
#   sampled valid (i,t,o) persönlich      #persönlich.    persönlich
#   sampled valid (i,t,o) Delegationen    #Delegation.    Delegation
#   sampled valid (i,t,o) dementiert      #dementieren.   dementiertn
#   sampled valid (i,t,o) Anspannung      #Anspannung.    Anspannung
#   sampled valid (i,t,o) auftrat         #auftreten.     auftraten
#   sampled valid (i,t,o) Resolution      #Resolution.    Resolution
#   sampled valid (i,t,o) verblassen      #verblassen.    verblassen
#   sampled valid (i,t,o) Erscheinung     #Erscheinung.   Erscheinung
#   sampled valid (i,t,o) Fahnenmasten    #Fahnenmast.    Fahnenmasteeeee
#   sampled valid (i,t,o) Griechenland    #Griechenland.  Griechenland
#   sampled valid (i,t,o) abgesperrt      #absperren.     absperren
#   sampled valid (i,t,o) Indonesian      #Indonesian.    Indonesian
#   sampled valid (i,t,o) Präsidenten     #Präsident.     Präsident
#   sampled valid (i,t,o) Deutschland     #Deutschland.   Deutschland
#   sampled valid (i,t,o) Kopfhörern      #Kopfhörer.     Kopfhörer
#   sampled valid (i,t,o) Bulgarien       #Bulgarien.     Bulgarien
# checkpoint...
# global step 4000 learning rate 0.8100 step-time 1.06 train perplexity 1.04
# run learning rate decay...
#   eval perplexity: 1.01
#   sampled valid (i,t,o) Hans       #Hans.     Hans
#   sampled valid (i,t,o) In         #in.       in
#   sampled valid (i,t,o) einmal     #einmal.   einmal
#   sampled valid (i,t,o) hat        #haben.    haben
#   sampled valid (i,t,o) Aber       #aber.     aber
#   sampled valid (i,t,o) in         #in.       in
#   sampled valid (i,t,o) Hans       #Hans.     Hans
#   sampled valid (i,t,o) Herr       #Herr.     Herr
#   sampled valid (i,t,o) Russen     #Russe.    Russe
#   sampled valid (i,t,o) weil       #weil.     weil
#   sampled valid (i,t,o) wie        #wie.      wie
#   sampled valid (i,t,o) des        #d.        d
#   sampled valid (i,t,o) sitzt      #sitzen.   sitzen
#   sampled valid (i,t,o) Krieg      #Krieg.    Krieg
#   sampled valid (i,t,o) Sprecher   #Sprecher. Sprecher
#   sampled valid (i,t,o) sich       #er.       er
#   sampled valid (i,t,o) Flur       #Flur.     Flur
#   sampled valid (i,t,o) und        #und.      und
#   sampled valid (i,t,o) ist        #sein.     sein
#   sampled valid (i,t,o) sich       #er.       er
# global step 4100 learning rate 0.7290 step-time 1.03 train perplexity 1.03
#   eval perplexity: 1.01
#   sampled valid (i,t,o) Irak       #Irak.     Irak
#   sampled valid (i,t,o) wird       #werden.   werden
#   sampled valid (i,t,o) kommt      #kommen.   kommen
#   sampled valid (i,t,o) wo         #wo.       wo
#   sampled valid (i,t,o) der        #d.        d
#   sampled valid (i,t,o) muss       #müssen.   müssen
# ...
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Friedensnobelpreisträger                           #Friedensnobelpreisträger.                         Friedensnobelpreisträger
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
#   sampled valid (i,t,o) Einerseits-andererseits-Reden                      #Einerseits-andererseits-Reden.                    Einerseits-andererseits-Aaden
